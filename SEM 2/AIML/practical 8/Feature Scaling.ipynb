# %%
# import the necessary libraries
import numpy as np
import pandas as pd

# %%
# create a dataframe by reading csv file
df=pd.read_csv("FeatureSelection.csv")

# %%
#display the dataframe
df.head()
# Out:
#    age  weight  height  cholestrol   sugar   Target
# 0   35      70     150          233     250       1
# 1   56      75     100          250     300       0
# 2   67      68     180          204     260       0
# 3   72      60     170          236     450       1
# 4   39      77     190          354     220       1

# %%
df.shape
# Out:
# (10, 6)

# %%
df.describe()
# Out:
#              age     weight      height  cholestrol       sugar      Target
# count  10.000000  10.000000   10.000000     10.00000   10.000000  10.000000
# mean   48.500000  65.400000  157.300000    239.30000  276.000000   0.600000
# std    13.769935   7.214184   39.994583     54.83926   97.661547   0.516398
# min    30.000000  57.000000  100.000000    168.00000  100.000000   0.000000
# 25%    39.500000  59.250000  120.000000    200.25000  227.500000   0.000000
# 50%    45.000000  65.000000  172.500000    234.50000  270.000000   1.000000
# 75%    55.750000  69.500000  187.500000    259.75000  337.500000   1.000000
# max    72.000000  77.000000  200.000000    354.00000  450.000000   1.000000

# %%
#copy the dataframe to another dataframe
df1=df.copy()

# %%
df1
# Out:
#    age  weight  height  cholestrol   sugar   Target
# 0   35      70     150          233     250       1
# 1   56      75     100          250     300       0
# 2   67      68     180          204     260       0
# 3   72      60     170          236     450       1
# 4   39      77     190          354     220       1
# 5   48      68     110          192     360       1
# 6   55      62     200          294     190       0
# 7   42      59     175          263     350       0
# 8   30      58     198          199     280       1
# 9   41      57     100          168     100       1

# %%
#Normalization Scaling by using min max value
for column in df1.columns:
    df1[column]=(df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())

# %% [markdown]
# new_value=old_value-min/max-min(1-0)+0

# %%
df1
# Out:
#         age  weight  height  cholestrol     sugar   Target
# 0  0.119048    0.65    0.50     0.349462  0.428571     1.0
# 1  0.619048    0.90    0.00     0.440860  0.571429     0.0
# 2  0.880952    0.55    0.80     0.193548  0.457143     0.0
# 3  1.000000    0.15    0.70     0.365591  1.000000     1.0
# 4  0.214286    1.00    0.90     1.000000  0.342857     1.0
# 5  0.428571    0.55    0.10     0.129032  0.742857     1.0
# 6  0.595238    0.25    1.00     0.677419  0.257143     0.0
# 7  0.285714    0.10    0.75     0.510753  0.714286     0.0
# 8  0.000000    0.05    0.98     0.166667  0.514286     1.0
# 9  0.261905    0.00    0.00     0.000000  0.000000     1.0

# %%
df1.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Standardization (z score normalization)
# new_value=(old_value-mean of column)/std of same column
df2=df.copy()

# %%
for column in df2.columns:
    df2[column]=(df2[column]-df2[column].mean())/df2[column].std()

# %%
df2
# Out:
#         age    weight    height  cholestrol     sugar     Target
# 0 -0.980397  0.637633 -0.182525    -0.114881 -0.266226  0.774597
# 1  0.544665  1.330712 -1.432694     0.195116  0.245747 -1.161895
# 2  1.343507  0.360401  0.567577    -0.643699 -0.163831 -1.161895
# 3  1.706617 -0.748525  0.317543    -0.060176  1.781663  0.774597
# 4 -0.689909  1.607944  0.817611     2.091567 -0.573409  0.774597
# 5 -0.036311  0.360401 -1.182660    -0.862521  0.860113  0.774597
# 6  0.472043 -0.471294  1.067645     0.997461 -0.880592 -1.161895
# 7 -0.472043 -0.887141  0.442560     0.432172  0.757719 -1.161895
# 8 -1.343507 -1.025757  1.017638    -0.734875  0.040958  0.774597
# 9 -0.544665 -1.164373 -1.432694    -1.300163 -1.802142  0.774597

# %%
df2.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
data=np.array([[10],[20],[30],[40]])

# %%
scaler=StandardScaler()

# %%
transformed_data=scaler.fit_transform(data)

# %%
print("Transformed Data:\n",transformed_data)
# Out:
# Transformed Data:
#  [[-1.34164079]
#  [-0.4472136 ]
#  [ 0.4472136 ]
#  [ 1.34164079]]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaled_data=scaler.fit_transform(data)

# %%
print("Normalized Data:\n",scaled_data)
# Out:
# Normalized Data:
#  [[0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
data=load_iris()

# %%
data

# %%
X=data.data#features
y=data.target#class

# %%
selector=SelectKBest(score_func=chi2,k=2)#score_fun -> function name, k-> no of features

# %%
X_new=selector.fit_transform(X,y)

# %%
print("Original Shape",X.shape)
# Out:
# Original Shape (150, 4)

# %%
print("Reduced shape:",X_new.shape)
# Out:
# Reduced shape: (150, 2)
